# %%
import pandas as pd

# %%
df = pd.read_csv('Churn_Modelling.csv')
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
df.drop(columns=['RowNumber','CustomerId','Surname'],inplace=True)

# %%
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
geography = pd.get_dummies(df['Geography'])
gender = pd.get_dummies(df['Geography'])

# %%
df = pd.concat([df,geography,gender],axis=1)

# %%
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited  France  Germany  \
# 0             1               1        101348.88       1    True    False
# 1             0               1        112542.58       0   False    False
# 2             1               0        113931.57       1    True    False
# 3             0               0         93826.63       0    True    False
# 4             1               1         79084.10       0   False    False
# ...         ...             ...              ...     ...     ...      ...
# 9995          1               0         96270.64       0    True    False
# 9996          1               1        101699.77       0    True    False
# 9997          0               1         42085.58       1    True    False
# 9998          1               0         92888.52       1   False     True
# 9999          1               0         38190.78       0    True    False
#
#       Spain  France  Germany  Spain
# 0     False    True    False  False
# 1      True   False    False   True
# 2     False    True    False  False
# 3     False    True    False  False
# 4      True   False    False   True
# ...     ...     ...      ...    ...
# 9995  False    True    False  False
# 9996  False    True    False  False
# 9997  False    True    False  False
# 9998  False   False     True  False
# 9999  False    True    False  False
#
# [10000 rows x 17 columns]

# %%
df.drop(columns=['Geography','Gender'],inplace=True)

# %%
df
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  France  Germany  Spain  France  \
# 0                  1        101348.88       1    True    False  False    True
# 1                  1        112542.58       0   False    False   True   False
# 2                  0        113931.57       1    True    False  False    True
# 3                  0         93826.63       0    True    False  False    True
# 4                  1         79084.10       0   False    False   True   False
# ...              ...              ...     ...     ...      ...    ...     ...
# 9995               0         96270.64       0    True    False  False    True
# 9996               1        101699.77       0    True    False  False    True
# 9997               1         42085.58       1    True    False  False    True
# 9998               0         92888.52       1   False     True  False   False
# 9999               0         38190.78       0    True    False  False    True
#
#       Germany  Spain
# 0       False  False
# 1       False   True
# 2       False  False
# 3       False  False
# 4       False   True
# ...       ...    ...
# 9995    False  False
# 9996    False  False
# 9997    False  False
# 9998     True  False
# 9999    False  False
#
# [10000 rows x 15 columns]

# %%
x = df.drop(['Exited'],axis=1)

# %%
y=df['Exited']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
x_train = scalar.fit_transform(x_train)
x_test = scalar.fit_transform(x_test)

# %%
import keras 
from keras.models import Sequential
from keras.layers import Dense

# %%
classifier = Sequential()
classifier.add(Dense(activation = 'relu',input_dim=14,units=6,kernel_initializer = 'uniform'))
classifier.add(Dense(activation = 'relu',units=6,kernel_initializer='uniform'))
classifier.add(Dense(activation = 'sigmoid',units=1))
classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
classifier.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 6)                 90
#
#  dense_8 (Dense)             (None, 6)                 42
#
#  dense_9 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 139 (556.00 Byte)
# Trainable params: 139 (556.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
classifier.fit(x_train,y_train,epochs=10,batch_size=10)
# Out:
# Epoch 1/10
# 800/800 [==============================] - 3s 2ms/step - loss: 0.4772 - accuracy: 0.7949
# Epoch 2/10
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4329 - accuracy: 0.7954
# Epoch 3/10
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4288 - accuracy: 0.8124
# Epoch 4/10
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4259 - accuracy: 0.8177
# Epoch 5/10
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4238 - accuracy: 0.8215
# Epoch 6/10
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4226 - accuracy: 0.8213
# Epoch 7/10
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4211 - accuracy: 0.8250
# Epoch 8/10
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4191 - accuracy: 0.8238
# Epoch 9/10
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4170 - accuracy: 0.8316
# Epoch 10/10
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4142 - accuracy: 0.8329

# %%
pred = classifier.predict(x_test)
# Out:
# 63/63 [==============================] - 0s 3ms/step

# %%
y_pred = pred>0.5

# %%
y_pred
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score

# %%
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[1569,   31],
#        [ 306,   94]])

# %%
recall = recall_score(y_test,y_pred)
recall
# Out:
# 0.235

# %%
acc = accuracy_score(y_test,y_pred)
acc
# Out:
# 0.8315

# %%
pre = precision_score(y_test,y_pred)
pre
# Out:
# 0.752
